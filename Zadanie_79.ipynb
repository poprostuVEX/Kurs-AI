# %% [markdown]
# <a href="https://colab.research.google.com/github/poprostuVEX/Kurs-AI/blob/main/Zadanie_79.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=['Azot','Tlen','Inne gazy']
y=[78,21,1]
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff376659160>,
# ...
#  [Text(-0.8475645981486316, 0.7011663511358405, 'Azot'),
#   Text(0.8251220897054863, -0.7274431504111175, 'Tlen'),
#   Text(1.0994572055257903, -0.034552181080508775, 'Inne gazy')])
